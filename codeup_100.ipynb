# %% [markdown]
# ### 006

# %%
print('"' '!@#$%^&*()' "'")
# Out:
# "!@#$%^&*()'

# %% [markdown]
# ### 007
# print out this path including "" : "C:\Download\\'hello'.py"<br/>

# %%
print('"'"C:\Download\\'hello'.py"'"')
# Out:
# "C:\Download\'hello'.py"

# %% [markdown]
# ### 008

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print('print''(''"Hello\\nWorld"'')')
# Out:
# print("Hello\nWorld")
