# %% [markdown]
# ### 006

# %%
print('"' '!@#$%^&*()' "'")
# Out:
# "!@#$%^&*()'

# %% [markdown]
# ### 007
# print out this path including "" : "C:\Download\\'hello'.py"<br/>

# %%
print('"'"C:\Download\\'hello'.py"'"')
# Out:
# "C:\Download\'hello'.py"

# %% [markdown]
# ### 008

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print('print''(''"Hello\\nWorld"'')')
# Out:
# print("Hello\nWorld")

# %% [markdown]
# ### 020

# %%
x, y = input().split('-')
print(x + y)
# Out:
# 950322-2423212
# 9503222423212

# %% [markdown]
# ### 021

# %%
s = input()

for i in range(len(s)):
    print(s[i])
# Out:
# hello

# %% [markdown]
# ### 022

# %%
x = input()
print(x[0:2], x[2:4], x[4:6])
# Out:
# 950322
# 95 03 22

# %% [markdown]
# ### 023

# %%
x, y, z = input().split(':')
print(y)
# Out:
# 17:23:57
# 23

# %% [markdown]
# ### 024

# %%
x, y = input().split()
print(x+y)
# Out:
# hello world
# helloworld

# %% [markdown]
# ### 025

# %%
x, y = input().split()
c = int(x) + int(y)
print(c)
# Out:
# 123 -123
# 0

# %% [markdown]
# ### 026

# %%
x = input()
y = input()
z = float(x) + float(y)
print(z)
# Out:
# 0.1
# 0.9
# 1.0

# %% [markdown]
# ### 027

# %%
a = input()
n = int(a) # convert a into octal number 
print('%x'%n) # convert n into hexadecimal number as lower case
# Out:
# 255
# ff

# %%
a = input()
n = int(a) # convert a into octal number as upper case
print('%X'%n)
# Out:
# 255
# FF

# %% [markdown]
# ### 028

# %%
a = input()
n = int(a, 16) # recognize a as hexadecimal number
print('%o'% n) # print out value in n as a octal number

# %% [markdown]
# ### 030

# %%
n = ord(input()) # convert input into octal number
print(n)
# Out:
# A
# 65

# %% [markdown]
# ### 033

# %%
n = input()
# Out:
# a

# %%
ord_n = ord(n) # ord : convert string into integer
print(ord_n)
# Out:
# 97

# %%
chr_n_1 = chr(ord_n+1)# chr : convert string into integer
print(chr_n_1)
# Out:
# b

# %%
n = input()
ord_n = ord(n)
print(ord_n)

chr_n = chr(ord_n)
print(chr_n)

chr_n_1 = chr(ord_n+1)
print(chr_n_1)
# Out:
# 5
# 53
# 5
# 6

# %%
n = input()
print(n+1) # str + int = impossible
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-d8ffa61dbbd2> in <module>
#       1 n = input()
# ----> 2 print(n+1)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### 034

# %%
a, b = input().split()
# Out:
# 123 -123

# %%
print(int(a) - int(b))
# Out:
# 246

# %%
a, b = int(input()).split()
# Out:
# -123 123
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-cda29a28dcfb> in <module>
# ----> 1 a, b = int(input()).split()
#
# ValueError: invalid literal for int() with base 10: '-123 123'

# %% [markdown]
# ### 035

# %%
a, b = input().split()
# Out:
# 0.5 2.0

# %%
print(float(a) * float(b))
# Out:
# 1.0

# %% [markdown]
# ### 036

# %%
w, n = input().split()
print(w*int(n))
# Out:
# love 3
# lovelovelove

# %% [markdown]
# ### 037

# %%
n = input()
s = input()
print(int(n)*s)
# Out:
# 3
# I AM INA
# I AM INAI AM INAI AM INA

# %% [markdown]
# ### 038

# %%
a, b = input().split()
print(int(a) ** int(b))
# Out:
# 2 10
# 1024

# %% [markdown]
# ### 039

# %%
a, b = input().split()
print(int(a) // int(b))
# Out:
# 10 3
# 3

# %% [markdown]
# ### 041

# %%
a, b = input().split()
print(int(a) % int(b))
# Out:
# 4 2
# 0

# %% [markdown]
# ### 042

# %%
a = input()
print(round(float(a), 2))
# Out:
# 3.141592
# 3.14

# %% [markdown]
# ### 043

# %%
a, b = input().split()
# Out:
# 10 3

# %%
c = float(a) / float(b)

# %%
print(c)
# Out:
# 3.3333333333333335

# %%
print('%.3f'%c)
# Out:
# 3.333

# %%
print('%.3f'%(float(a) / float(b)))
# Out:
# 3.333

# %% [markdown]
# ### 044

# %%
a, b = input().split()
print(int(a) + int(b))
print(int(a) - int(b))
print(int(a) * int(b))
print(int(a) // int(b))
print(int(a)%int(b))
print('%.2f'%(int(a) / int(b)))
# Out:
# 10 3
# 13
# 7
# 30
# 3
# 1
# 3.33

# %% [markdown]
# ### 045

# %%
a, b, c = input().split()
d = int(a) + int(b) + int(c)
e = d / 3
print(d, '%.1f'%e)
# Out:
# 1 2 3
# 6 2.0
